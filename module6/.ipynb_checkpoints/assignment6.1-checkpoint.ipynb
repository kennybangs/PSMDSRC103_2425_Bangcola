# %%
#Assignment 6.1 - Karim Bangcola Jr

#Part 1

import random
import math
random.seed(0)
salaries = [round(random.random()*1000000, -3) for _ in range(100)]

#Without using the statistics module, compute for the ff:
#Mean
#Median
#Mode
#Sample variance
#Sample stdev

length = len(salaries)

#Mean

mean = sum(salaries)/length
print("Mean: " + str(mean))

#Median
if len(salaries) % 2 == 0:
    median = (salaries[int(length/2)]+salaries[int(length/2)+1])/2
else:
    median = salaries[int((length+1)/2)]

print("Median: " + str(median))

#Mode
countDict = {}
#count number of occurences per list item
for x in salaries:
    countDict[x] = salaries.count(x)

ranked = list(countDict.values())
ranked.sort(reverse=True)
ranked[0]

for value, occurences in countDict.items():  # for name, age in dictionary.iteritems():  (for Python 2.x)
    if occurences == ranked[0]:
        print("Mode: " + str(value))

#Sample variance
sampleSums = []
for x in salaries:
    sampleSums.append(x-mean)
#print(sampleSums)
sampleVariance = sum(sampleSums)**2/(length-1)
print("Sample variance: " + str(sampleVariance))

#Sample stdev
sampleStdev = math.sqrt(sampleVariance)
print(sampleStdev)
# Out:
# Mean: 585690.0
# Median: 625500.0
# Mode: 477000.0
# Sample variance: 0.0
# 0.0

# %%
#using statistics module

import statistics as stat

print("Mean: " + str(stat.mean(salaries)))
print("Median: " + str(stat.median(salaries)))
print("Mode: " + str(stat.mode(salaries)))
print("Variance: " + str(stat.variance(salaries)))
print("Stdev: " + str(stat.stdev(salaries)))
# Out:
# Mean: 585690.0
# Median: 589000.0
# Mode: 477000.0
# Variance: 70664054444.44444
# Stdev: 265827.11382484

# %%
#Part 2: Load diabetes.csv and perform the following tasks:

import pandas as pd

diabetes_df = pd.read_csv('diabetes.csv')

#Identify the column names:

diabetes_df.columns
# Out:
# Index(['Pregnancies', 'Glucose', 'BloodPressure', 'SkinThickness', 'Insulin',
#        'BMI', 'DiabetesPedigreeFunction', 'Age', 'Outcome'],
#       dtype='object')

# %%
#Identify the data types of the data

diabetes_df.dtypes
# Out:
# Pregnancies                   int64
# Glucose                       int64
# BloodPressure                 int64
# SkinThickness                 int64
# Insulin                       int64
# BMI                         float64
# DiabetesPedigreeFunction    float64
# Age                           int64
# Outcome                       int64
# dtype: object

# %%
#Display total number of records

diabetes_df.index
# Out:
# RangeIndex(start=0, stop=768, step=1)

# %%
#Display first 20 rows

diabetes_df[0:20]
# Out:
#     Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0             6      148             72             35        0  33.6
# 1             1       85             66             29        0  26.6
# 2             8      183             64              0        0  23.3
# 3             1       89             66             23       94  28.1
# 4             0      137             40             35      168  43.1
# 5             5      116             74              0        0  25.6
# 6             3       78             50             32       88  31.0
# 7            10      115              0              0        0  35.3
# 8             2      197             70             45      543  30.5
# 9             8      125             96              0        0   0.0
# 10            4      110             92              0        0  37.6
# 11           10      168             74              0        0  38.0
# ...

# %%
#Display last 20 rows

diabetes_df[-20:]
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 748            3      187             70             22      200  36.4
# 749            6      162             62              0        0  24.3
# 750            4      136             70              0        0  31.2
# 751            1      121             78             39       74  39.0
# 752            3      108             62             24        0  26.0
# 753            0      181             88             44      510  43.3
# 754            8      154             78             32        0  32.4
# 755            1      128             88             39      110  36.5
# 756            7      137             90             41        0  32.0
# 757            0      123             72              0        0  36.3
# 758            1      106             76              0        0  37.5
# 759            6      190             92              0        0  35.5
# ...

# %%
#Change the outcome column to Diagnosis

diabetes_df.rename(columns={"Outcome":"Diagnosis"},inplace=True)
diabetes_df.columns
# Out:
# Index(['Pregnancies', 'Glucose', 'BloodPressure', 'SkinThickness', 'Insulin',
#        'BMI', 'DiabetesPedigreeFunction', 'Age', 'Diagnosis'],
#       dtype='object')

# %%
#Create a new column classification

classification=[]

for x in diabetes_df['Diagnosis']:
    if x == 1:
        classification.append("Diabetes")
    else:
        classification.append("No diabates")

diabetes_df.insert(9,'Classification',classification)

# %%
diabetes_df.head
# Out:
# <bound method NDFrame.head of      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6      148             72             35        0  33.6
# 1              1       85             66             29        0  26.6
# 2              8      183             64              0        0  23.3
# 3              1       89             66             23       94  28.1
# 4              0      137             40             35      168  43.1
# ..           ...      ...            ...            ...      ...   ...
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 766            1      126             60              0        0  30.1
# 767            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age  Diagnosis Classification
# ...

# %%
#Create a new dataframe withDiabetes that gathers data with diabetes

withDiabetes = diabetes_df[diabetes_df["Classification"]=="Diabetes"]
withDiabetes
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6      148             72             35        0  33.6
# 2              8      183             64              0        0  23.3
# 4              0      137             40             35      168  43.1
# 6              3       78             50             32       88  31.0
# 8              2      197             70             45      543  30.5
# ..           ...      ...            ...            ...      ...   ...
# 755            1      128             88             39      110  36.5
# 757            0      123             72              0        0  36.3
# 759            6      190             92              0        0  35.5
# 761            9      170             74             31        0  44.0
# 766            1      126             60              0        0  30.1
#
#      DiabetesPedigreeFunction  Age  Diagnosis Classification
# ...

# %%
#Create a new dataframe noDiabetes that gathers data with no diabetes

noDiabetes = diabetes_df[diabetes_df["Classification"]=="No diabates"]
noDiabetes
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 1              1       85             66             29        0  26.6
# 3              1       89             66             23       94  28.1
# 5              5      116             74              0        0  25.6
# 7             10      115              0              0        0  35.3
# 10             4      110             92              0        0  37.6
# ..           ...      ...            ...            ...      ...   ...
# 762            9       89             62              0        0  22.5
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 767            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age  Diagnosis Classification
# ...

# %%
#Create a new dataframe Pedia that gathers data with age 0 to 19

pedia = diabetes_df[diabetes_df["Age"]<=19]
pedia

#As per checking, there are no pedia cases present in our dataset
# Out:
# Empty DataFrame
# Columns: [Pregnancies, Glucose, BloodPressure, SkinThickness, Insulin, BMI, DiabetesPedigreeFunction, Age, Diagnosis, Classification]
# Index: []

# %%
#Create a new dataframe Adult that gathers data with age greater than 19

adult = diabetes_df[diabetes_df["Age"]>19]
adult
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6      148             72             35        0  33.6
# 1              1       85             66             29        0  26.6
# 2              8      183             64              0        0  23.3
# 3              1       89             66             23       94  28.1
# 4              0      137             40             35      168  43.1
# ..           ...      ...            ...            ...      ...   ...
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 766            1      126             60              0        0  30.1
# 767            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age  Diagnosis Classification
# ...

# %%
#Numpy work

#Average Age

diabetes_df['Age'].mean()
# Out:
# 33.240885416666664

# %%
#Average glucose value

diabetes_df['Glucose'].mean()
# Out:
# 120.89453125

# %%
#median Age

diabetes_df['Age'].median()
# Out:
# 29.0

# %%
#Median glucose value

diabetes_df['Glucose'].median()
# Out:
# 117.0

# %%
#Stdev of skinthickness

diabetes_df['SkinThickness'].std()
# Out:
# 15.952217567727637

# %%
#Part 3, own dataset

from ucimlrepo import fetch_ucirepo 
  
# fetch dataset 
bank_marketing = fetch_ucirepo(id=222) 
  
# data (as pandas dataframes) 
X = bank_marketing.data.features 
y = bank_marketing.data.targets 
  
# metadata 
print(bank_marketing.metadata) 
  
# variable information 
print(bank_marketing.variables)
# Out:
# {'uci_id': 222, 'name': 'Bank Marketing', 'repository_url': 'https://archive.ics.uci.edu/dataset/222/bank+marketing', 'data_url': 'https://archive.ics.uci.edu/static/public/222/data.csv', 'abstract': 'The data is related with direct marketing campaigns (phone calls) of a Portuguese banking institution. The classification goal is to predict if the client will subscribe a term deposit (variable y).', 'area': 'Business', 'tasks': ['Classification'], 'characteristics': ['Multivariate'], 'num_instances': 45211, 'num_features': 16, 'feature_types': ['Categorical', 'Integer'], 'demographics': ['Age', 'Occupation', 'Marital Status', 'Education Level'], 'target_col': ['y'], 'index_col': None, 'has_missing_values': 'yes', 'missing_values_symbol': 'NaN', 'year_of_dataset_creation': 2014, 'last_updated': 'Fri Aug 18 2023', 'dataset_doi': '10.24432/C5K306', 'creators': ['S. Moro', 'P. Rita', 'P. Cortez'], 'intro_paper': {'ID': 277, 'type': 'NATIVE', 'title': 'A data-driven approach to predict the
# ...

# %%
#Display the first 10 and last 10 rows.

X[:20]
# Out:
#     age           job   marital  education default  balance housing loan  \
# 0    58    management   married   tertiary      no     2143     yes   no
# 1    44    technician    single  secondary      no       29     yes   no
# 2    33  entrepreneur   married  secondary      no        2     yes  yes
# 3    47   blue-collar   married        NaN      no     1506     yes   no
# 4    33           NaN    single        NaN      no        1      no   no
# 5    35    management   married   tertiary      no      231     yes   no
# 6    28    management    single   tertiary      no      447     yes  yes
# 7    42  entrepreneur  divorced   tertiary     yes        2     yes   no
# 8    58       retired   married    primary      no      121     yes   no
# 9    43    technician    single  secondary      no      593     yes   no
# 10   41        admin.  divorced  secondary      no      270     yes   no
# 11   29        admin.    single  secondary      no      390     yes   no
# ...

# %%
#Last 20 rows
X[-20:]
# Out:
#        age            job   marital  education default  balance housing loan  \
# 45191   75        retired  divorced   tertiary      no     3810     yes   no
# 45192   29     management    single   tertiary      no      765      no   no
# 45193   28  self-employed    single   tertiary      no      159      no   no
# 45194   59     management   married   tertiary      no      138     yes  yes
# 45195   68        retired   married  secondary      no     1146      no   no
# 45196   25        student    single  secondary      no      358      no   no
# 45197   36     management    single  secondary      no     1511     yes   no
# 45198   37     management   married   tertiary      no     1428      no   no
# 45199   34    blue-collar    single  secondary      no     1475     yes   no
# 45200   38     technician   married  secondary      no      557     yes   no
# 45201   53     management   married   tertiary      no      583      no   no
# ...

# %%
#Choose a column with a numerical value, change its type to int64 and store in a new column.

#Change datatype of balance to int64
X.astype({'balance':'int64'})

#Store in a new column
#X.insert(16,'balanceInt64',X['balance'])

X.columns
X[:20]
# Out:
#     age           job   marital  education default  balance housing loan  \
# 0    58    management   married   tertiary      no     2143     yes   no
# 1    44    technician    single  secondary      no       29     yes   no
# 2    33  entrepreneur   married  secondary      no        2     yes  yes
# 3    47   blue-collar   married        NaN      no     1506     yes   no
# 4    33           NaN    single        NaN      no        1      no   no
# 5    35    management   married   tertiary      no      231     yes   no
# 6    28    management    single   tertiary      no      447     yes  yes
# 7    42  entrepreneur  divorced   tertiary     yes        2     yes   no
# 8    58       retired   married    primary      no      121     yes   no
# 9    43    technician    single  secondary      no      593     yes   no
# 10   41        admin.  divorced  secondary      no      270     yes   no
# 11   29        admin.    single  secondary      no      390     yes   no
# ...

# %%
#Choose a column with a non-numerical value (that can act as a category), create a new column that contains the mapped values of 
#the categorical column from 0 to n-1. (E.g. Iris-Setosa is 0, Iris-versicolor is 1, Iris-virginica is 2).

#Using marital column

classification=[]

for y in X['marital']:
    if y == 'single':
        classification.append(1)
    elif y == 'married':
         classification.append(2)
    else:
        classification.append(0)

X.insert(17,'maritalClassification',classification)

X[:10]
# Out:
#    age           job   marital  education default  balance housing loan  \
# 0   58    management   married   tertiary      no     2143     yes   no
# 1   44    technician    single  secondary      no       29     yes   no
# 2   33  entrepreneur   married  secondary      no        2     yes  yes
# 3   47   blue-collar   married        NaN      no     1506     yes   no
# 4   33           NaN    single        NaN      no        1      no   no
# 5   35    management   married   tertiary      no      231     yes   no
# 6   28    management    single   tertiary      no      447     yes  yes
# 7   42  entrepreneur  divorced   tertiary     yes        2     yes   no
# 8   58       retired   married    primary      no      121     yes   no
# 9   43    technician    single  secondary      no      593     yes   no
#
#   contact  day_of_week month  duration  campaign  pdays  previous poutcome  \
# 0     NaN            5   may       261         1     -1         0      NaN
# ...

# %%
#Create a column that would have the value YES or NO depending on a conditional statement you will create 
#based on values in the dataset. (E.g. "Age > 18 == Adult | YES OR NO")

#Using marital column

classification=[]

for y in X['balance']:
    if y >= 1000:
        classification.append("YES")
    else:
        classification.append("NO")

X.insert(18,'balanceAbove1000',classification)

X[:20]
# Out:
#     age           job   marital  education default  balance housing loan  \
# 0    58    management   married   tertiary      no     2143     yes   no
# 1    44    technician    single  secondary      no       29     yes   no
# 2    33  entrepreneur   married  secondary      no        2     yes  yes
# 3    47   blue-collar   married        NaN      no     1506     yes   no
# 4    33           NaN    single        NaN      no        1      no   no
# 5    35    management   married   tertiary      no      231     yes   no
# 6    28    management    single   tertiary      no      447     yes  yes
# 7    42  entrepreneur  divorced   tertiary     yes        2     yes   no
# 8    58       retired   married    primary      no      121     yes   no
# 9    43    technician    single  secondary      no      593     yes   no
# 10   41        admin.  divorced  secondary      no      270     yes   no
# 11   29        admin.    single  secondary      no      390     yes   no
# ...
