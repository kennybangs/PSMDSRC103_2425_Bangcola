# %% [markdown]
# # Assessment 3.2 | Prelim Skills Exam
# PSMDSRC103 - Programming

# %% [markdown]
# ## Area 1: Understanding Objects

# %% [markdown]
# 1. Define a class called Address that has two attributes: `number` and `street name`. Make sure you have an `init` method that initializes the object appropriately. You do not need to define any other methods.

# %%
class Address():
  def __init__(self, number, street_name):
    self.number = number
    self.street_name = street_name

print(help(Address))
# Out:
# Help on class Address in module __main__:
#
# class Address(builtins.object)
#  |  Address(number, street_name)
#  |
#  |  Methods defined here:
#  |
#  |  __init__(self, number, street_name)
#  |      Initialize self.  See help(type(self)) for accurate signature.
#  |
#  |  ----------------------------------------------------------------------
#  |  Data descriptors defined here:
#  |
#  |  __dict__
#  |      dictionary for instance variables (if defined)
#  |
#  |  __weakref__
#  |      list of weak references to the object (if defined)
#
# None

# %% [markdown]
# 2. Consider the following code:
# ```
#   class Clock(object):
#       def __init__(self, time):
#           self.time = time
#       def print_time(self):
#           time = ’6:30’
#           print self.time
#    clock = Clock(’5:30’)
#    clock.print_time()
# ```

# %% [markdown]
# (a) What does the code print out? Guess first, and then create a Python file and run it.

# %%
#it should print out 5:30 since time = '6:30' modifies the parent attribute time
#and not the time of the specific instance.

class Clock(object):
   def __init__(self, time):
       self.time = time
   def print_time(self):
       time ='’6:30'
       print(self.time)
clock = Clock('5:30')
clock.print_time()
# Out:
# 5:30

# %% [markdown]
# (b) Why does the code print this?

# %% [markdown]
# #the code time='6:30' applies to the parent attribute time
# #and not the attribute of the instance clock. Since '5:30'
# #is passed to the time of the specific instance and print_time
# #prints that, 5:30 is displayed

# %% [markdown]
# 3. Consider the following code:
# ```
#   class Clock(object):
#       def __init__(self, time):
#           self.time = time
#       def print_time(self, time):
#           print time
#    clock = Clock(’5:30’)
#    clock.print_time(’10:30’)
# ```

# %% [markdown]
# (a) What does the code print out? Guess first, and then create a Python file and run it.

# %%
#i guess it will print out 5:30 since time is set to 5:30
#and the parameter 10:30 will not override the self.time

class Clock(object):
   def __init__(self, time):
       self.time = time
   def print_time(self, time):
       print(time)
clock = Clock('5:30')
clock.print_time('10:30')
# Out:
# 10:30

# %% [markdown]
# (b) What does this tell you about giving parameters the same name as object attributes?

# %% [markdown]
# #my guess was wrong - the opposite happened - 10:30 was displayed
# #instead of 5:30. this is because 10:30 took precedence over
# #attribute self.time because the argument of print_time has the
# #same name of the attribute time#i

# %% [markdown]
# 4. Consider the following code:
# ```
#    class Clock(object):
#        def __init__(self, time):
#           self.time = time
#        def print_time(self):
#           print self.time
#    boston_clock = Clock(’5:30’)
#    paris_clock = boston_clock
#    paris_clock.time = ’10:30’
#    boston_clock.print_time()
# ```

# %% [markdown]
# (a) What does the code print out? Guess first, and then create a Python file and run it.

# %%
#i guess it will print out 5:30. this is because while paris_clock
#inherits from boston_clock, they are not the same object

class Clock(object):
    def __init__(self, time):
       self.time = time
    def print_time(self):
       print(self.time)
boston_clock = Clock('5:30')
paris_clock = boston_clock
paris_clock.time = '10:30'
boston_clock.print_time()

print(help(paris_clock))
# Out:
# 10:30
# Help on Clock in module __main__ object:
#
# class Clock(builtins.object)
#  |  Clock(time)
#  |
#  |  Methods defined here:
#  |
#  |  __init__(self, time)
#  |      Initialize self.  See help(type(self)) for accurate signature.
#  |
#  |  print_time(self)
#  |
#  |  ----------------------------------------------------------------------
#  |  Data descriptors defined here:
#  |
#  |  __dict__
#  |      dictionary for instance variables (if defined)
#  |
#  |  __weakref__
#  |      list of weak references to the object (if defined)
#
# None

# %% [markdown]
# (b) Why does it print what it does? (Are boston clock and paris clock different objects? Why or why not?)

# %% [markdown]
# #my guess was wrong - modifying the time of paris clock also changed the time of boston clock. this means that they are actually the same instance of the class Clock, just with different names.

# %% [markdown]
# ## Area 2: Designing Your Own Class
# For this exercise, you will be coding your very first class, a Queue class. Queues are a fundamental computer science data structure. A queue is basically like a line at Disneyland - you can add elements to a queue, and they maintain a specific order. When you want to get something off the end of a queue, you get the item that has been in there the longest (this is known as ‘first-in-first-out’, or FIFO). You can read up on queues at Wikipedia if you’d like to learn more.

# %% [markdown]
# Create a new file called `queue.py` to make your Queue class.
# In your Queue class, you will need three methods:
# * init : to initialize your Queue (think: how will you store the queue’s elements? You’ll need to initialize
# an appropriate object attribute in this method)
# * insert: inserts one element in your Queue
# * remove: removes one element from your Queue and returns it. If the queue is empty, return a message that says it is empty (without throwing an error that halts your code).
#
# When you’re done, you should test your implementation. Your results should look like this:
# ```
# >> queue = Queue()
# >> queue.insert(5)
# >> queue.insert(6)
# >> queue.remove()
# 5
# >> queue.insert(7)
# >> queue.remove()
# 6
# >> queue.remove()
# 7
# >> queue.remove()
# The queue is empty
# ```
#
# Be sure to handle that last case correctly - when popping from an empty Queue, print a message rather than throwing an error.

# %%
class Queue():

    def __init__(self):
        self.queue = []

    def insert(self,item):
        self.queue.append(item)

    def remove(self):
       if len(self.queue) == 0:
           print('the queue is empty')
       else:
           print(self.queue.pop(0))

queue = Queue()
queue.insert(5)
queue.insert(6)
queue.insert(7)
queue.remove()
queue.remove()
queue.remove()
queue.remove()
# Out:
# 5
# 6
# 7
# the queue is empty

# %% [markdown]
# ## Area 3: OOP Paradigms
# For this exercise, we want you to describe a generic superclass and at least three subclasses of that superclass, listing at least two attributes that each class would have. Remember what classes will inherit (will subclasses inherit attributes from their parent class? Will parent classes inherit from their subclasses? Will subclasses that share a parent inherit from one another? Be sure you’re clear on this before continuing with this exercise.)
# It’s easiest to simply describe a real-world object in this manner. An example of what we’re looking for would be to describe a generic Shoe class and some specific subclasses with attributes that they might have, as shown here:
#
# ```
# class Shoe:
#    # Attributes: self.color, self.brand
# class Converse(Shoe): # Inherits from Shoe
#    # Attributes: self.lowOrHighTop, self.tongueColor, self.brand = "Converse"
# class CombatBoot(Shoe): # Inherits from Shoe
#    # Attributes: self.militaryBranch, self.DesertOrJungle
# class Sandal(Shoe): # Inherits from Shoe
#    # Attributes: self.openOrClosedToe, self.waterproof
# ```
#
# You can use any real-world object except a shoe for this problem :)

# %%
class Vehicle():
  """
  Attributes:
  self.wheels (number of)
  self.powerSource (electric/hybrid/combustion)
  self.seats (number of)
  self.doors (number of)
  self.brand
  self.serial_number
  self.year
  """

class CombustionCar(Vehicle): #inherit Vehicle attributes
  """
  Unique CombustionCar attributes:
  self.displacement (in CC)
  self.cylinders
  self.stroke (2/4)
  self.fuel (gas/diesel/etc)
  """

class ElectricCar(Vehicle): #inherit Vehicle attributes
  """
  Unique ElectricCar attributes:
  self.batterySize
  self.chargerType
  self.electricMotorType
  """

class HybridCar(CombustionCar,ElectricCar) #inherit Vehicle, Combustion, and
  #ElectricCar since hybrid is a combination of Combustion and electric:
  """
  Unique HybridCar attributes:
  self.drivetrain (split/series/parallel accdng to wikipedia)
  """

# %% [markdown]
# ## Conclusion & Analysis

# %% [markdown]
# Wrap up your skills exam by providing a brief analysis of what you've done so far.

# %%
"""
In this exam, we worked with objects and demonstrated the concepts of
inheritance, instances, attributes, and methods. We learned about the
difference between the attribute of the template class and the attributes
of its instances. To change the value of an attribute in one particular instance
only, we need to use the self prefix. if not, it will change the attribute in the
original template class.

We also learned about inheritance - a class can receive/inherit the attributes
and method of another class. This will create a parent and child relationship
between the two. We do this by specifying the name of the parent class in
parentheses when creating a class. In addition to the inherited attributes
and methods of the parent class, it can have its own original attributes
and methods that the parent class does not have.
"""
# Out:
#   File "<ipython-input-10-e4615a684824>", line 1
#     """
#     ^
# SyntaxError: incomplete input
